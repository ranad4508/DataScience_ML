# %%
#import pandas and pyplot 
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns  # Import seaborn library

# %%
#reading csv file
dataset = pd.read_csv("heart_disease.csv")
dataset
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
#Checking if dataset i.e csv file have empty field
dataset.isna().sum()
# Out:
# HeartDisease          0
# BMI                   6
# Smoking              74
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease        17
# SkinCancer            0
# dtype: int64

# %%
#Checking the data type of all the field
dataset.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
#Selecting the first five values
dataset.head(5)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
#Selecting the bottom five values
dataset.tail(5)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %% [markdown]
# #### 1.  Filling the missing values of 'BMI' field

# %%
dataset['BMI'].isna().sum()#Checking if BMI field have missing values
# Out:
# 6

# %%
dataset['BMI'].fillna(33.303, inplace=True) #Filling the missing values in BMI

# %%
dataset[dataset['BMI']==33.303] #Selecting the value just filled
# Out:
#     HeartDisease     BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 7             No  33.303     Yes              No     No             5.0
# 21            No  33.303      No              No     No             2.0
# 26            No  33.303     Yes              No     No            21.0
# 42           Yes  33.303      No              No     No             0.0
# 72            No  33.303      No              No     No             0.0
# 200           No  33.303      No             NaN     No             1.0
#
#      MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 7             0.0         Yes  Female  80 or older  White      Yes
# 21            5.0          No  Female        70-74  White      Yes
# 26            8.0         Yes  Female        65-69  White       No
# 42            0.0         Yes  Female  80 or older  White      Yes
# 72            5.0          No    Male        50-54  White      Yes
# ...

# %%
dataset['BMI'].isna().sum() #Checking if all the missing values are filled
# Out:
# 0

# %% [markdown]
# #### 2. Filling the missing values of 'Smoking' field

# %%
dataset['Smoking'].isna().sum() #Checing if smoking has missing values
# Out:
# 74

# %%
dataset['Smoking'] #Checing the values of Smoking
# Out:
# 0         Yes
# 1          No
# 2         Yes
# 3          No
# 4          No
#          ...
# 319790    Yes
# 319791    Yes
# 319792     No
# 319793     No
# 319794     No
# Name: Smoking, Length: 319795, dtype: object

# %%
dataset['Smoking'].fillna('No', inplace=True) #Filling missing values of Smoking

# %%
dataset['Smoking'].isna().sum() #Checking if all the missing values are filled
# Out:
# 0

# %%
dataset[dataset['Smoking']=='Yes'] #Selecting the values that we just filled
# Out:
#        HeartDisease     BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.600     Yes              No     No             3.0
# 2                No  26.580     Yes              No     No            20.0
# 5               Yes  28.870     Yes              No     No             6.0
# 7                No  33.303     Yes              No     No             5.0
# 10              Yes  34.300     Yes              No     No            30.0
# ...             ...     ...     ...             ...    ...             ...
# 319782           No  31.890     Yes              No     No            30.0
# 319784           No  26.580     Yes              No     No             0.0
# 319786          Yes  33.200     Yes              No     No             0.0
# 319790          Yes  27.410     Yes              No     No             7.0
# 319791           No  29.840     Yes              No     No             0.0
#
# ...

# %% [markdown]
# #### 3. Filling the missing values of 'AlcoholDrinking' field

# %%
dataset['AlcoholDrinking'].isna().sum() #Checking if missing values exists
# Out:
# 115

# %%
dataset['AlcoholDrinking'].fillna('Yes', inplace=True) #Filling the missing values

# %%
dataset['AlcoholDrinking'].isna().sum() #Checking if missing values are filled
# Out:
# 0

# %%
dataset[dataset['AlcoholDrinking']=='Yes'] #Selecting the values we just filled
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 55               No  24.02      No             Yes     No             7.0
# 96               No  24.02      No             Yes     No             0.0
# 97               No  28.35      No             Yes     No            20.0
# 98               No  24.37      No             Yes     No             0.0
# 99               No  19.47     Yes             Yes     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319699           No  27.46     Yes             Yes     No             0.0
# 319702           No  24.41      No             Yes     No             0.0
# 319704           No  29.53      No             Yes     No             0.0
# 319732           No  18.79      No             Yes     No            30.0
# 319785           No  31.93      No             Yes     No             0.0
#
#         MentalHealth DiffWalking     Sex AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# #### 4. Filling the missing values of 'Stroke' field

# %%
dataset['Stroke'].isna().sum() #Checking if values are missing in 'Stroke' field
# Out:
# 21

# %%
dataset['Stroke'] #Checking the values of 'Stroke' field
# Out:
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4          No
#          ...
# 319790     No
# 319791     No
# 319792     No
# 319793     No
# 319794     No
# Name: Stroke, Length: 319795, dtype: object

# %%
dataset['Stroke'].fillna('Yes', inplace=True) #Filling the missing values of 'Stroke' field

# %%
dataset[dataset['Stroke']=='Yes'] #Selecting the value we just filled
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 1                No  20.34      No              No    Yes             0.0
# 35              Yes  32.98     Yes              No    Yes            10.0
# 40               No  22.60     Yes              No    Yes             0.0
# 49               No  27.46     Yes              No    Yes            15.0
# 59               No  27.20     Yes              No    Yes             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319588           No  30.56      No              No    Yes            21.0
# 319619          Yes  39.31      No              No    Yes             3.0
# 319620          Yes  27.64      No              No    Yes             1.0
# 319740           No  26.07      No              No    Yes             0.0
# 319765          Yes  38.45      No              No    Yes            30.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# #### 5. Filling the missing values of 'PhysicalHealth' field

# %%
dataset['PhysicalHealth'].isna().sum() #Checking if 'PhysicalHealth' field has missing values
# Out:
# 17

# %%
dataset['PhysicalHealth'] #Checking the values of 'PhysicalHealth' field
# Out:
# 0          3.0
# 1          0.0
# 2         20.0
# 3          0.0
# 4         28.0
#           ...
# 319790     7.0
# 319791     0.0
# 319792     0.0
# 319793     0.0
# 319794     0.0
# Name: PhysicalHealth, Length: 319795, dtype: float64

# %%
dataset['PhysicalHealth'].fillna(11.11, inplace=True) #Filling the missing values of 'PhysicalHealth' field

# %%
dataset['PhysicalHealth'].isna().sum() #Checking if all the values are filled or not
# Out:
# 0

# %%
dataset[dataset['PhysicalHealth']==11.11] #Selecting the values that we just filled
# Out:
#     HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 345           No  35.24     Yes              No     No           11.11
# 346          Yes  29.04     Yes              No    Yes           11.11
# 347           No  26.43      No              No    Yes           11.11
# 348          Yes  27.89      No              No    Yes           11.11
# 349          Yes  26.26     Yes              No    Yes           11.11
# 350           No  27.44      No              No    Yes           11.11
# 351           No  29.95     Yes              No    Yes           11.11
# 352           No  32.28     Yes              No    Yes           11.11
# 353           No  25.84      No              No    Yes           11.11
# 354           No  33.99     Yes              No    Yes           11.11
# 355           No  28.25     Yes              No    Yes           11.11
# 356           No  19.20      No              No    Yes           11.11
# ...

# %% [markdown]
# #### 5. Filling the missing values of 'MentalHealth' field

# %%
dataset['MentalHealth'].isna().sum() #Checking the missing values of 'MentalHealth' field
# Out:
# 14

# %%
dataset['MentalHealth'] #Checking the values of 'MentalHealth' field
# Out:
# 0         30.0
# 1          0.0
# 2         30.0
# 3          0.0
# 4          0.0
#           ...
# 319790     0.0
# 319791     0.0
# 319792     0.0
# 319793     0.0
# 319794     0.0
# Name: MentalHealth, Length: 319795, dtype: float64

# %%
dataset['MentalHealth'].fillna(22.22, inplace=True) #Filling the missing values of 'MentalHealth' field

# %%
dataset['MentalHealth'].isna().sum() #Checking if all the values are filled or not
# Out:
# 0

# %%
dataset[dataset['MentalHealth']==22.22] #Selecting the values we just filled
# Out:
#     HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 686          Yes  55.85      No              No     No            30.0
# 687           No  23.71      No              No     No             0.0
# 688           No  26.61      No              No    Yes             0.0
# 689           No  32.11     Yes              No     No            30.0
# 690           No  29.95     Yes              No     No             0.0
# 691           No  23.49     Yes              No     No             0.0
# 692           No  20.61      No              No     No            10.0
# 693           No  31.75      No              No     No             0.0
# 694           No  26.97     Yes              No     No             0.0
# 695           No  28.17      No              No     No             0.0
# 696           No  32.50      No              No     No             0.0
# 697           No  24.28      No              No     No             0.0
# ...

# %% [markdown]
# #### 6. Filling the missing values of 'DiffWalking' field

# %%
dataset['DiffWalking'].isna().sum() #Checking if 'DiffWalking' field have missing values
# Out:
# 33

# %%
dataset['DiffWalking'] #Selecting the values of 'DiffWalking' field
# Out:
# 0          No
# 1          No
# 2          No
# 3          No
# 4         Yes
#          ...
# 319790    Yes
# 319791     No
# 319792     No
# 319793     No
# 319794     No
# Name: DiffWalking, Length: 319795, dtype: object

# %%
dataset['DiffWalking'].fillna('No', inplace=True) #Filling the missing values of 'DiffWalking' field

# %%
dataset['DiffWalking'].isna().sum() #Checking if missing values are filled or not
# Out:
# 0

# %%
dataset[dataset['DiffWalking']=='No'] #Selecting the values we just filled in 'DiffWalking' field
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 6                No  21.63      No              No     No            15.0
# ...             ...    ...     ...             ...    ...             ...
# 319789           No  22.22      No              No     No             0.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# #### 7. Filling the missing values of 'Sex' field

# %%
dataset['Sex'].isna().sum() #Checking is missing value exists in 'Sex' field
# Out:
# 313

# %%
dataset['Sex'].fillna('Male', inplace=True) #Filling the missing values of 'Sex' field

# %%
dataset['Sex'].isna().sum() #Checkig if all the values are filled
# Out:
# 0

# %%
dataset[dataset['Sex']=='Male'] #Selecting the values we just filled
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2                No  26.58     Yes              No     No            20.0
# 9                No  40.69      No              No     No             0.0
# 10              Yes  34.30     Yes              No     No            30.0
# 12               No  28.37     Yes              No     No             0.0
# 17               No  22.59     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319784           No  26.58     Yes              No     No             0.0
# 319785           No  31.93      No             Yes     No             0.0
# 319787           No  36.54      No              No     No             7.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
#
#         MentalHealth DiffWalking   Sex AgeCategory      Race  \
# ...

# %% [markdown]
# #### 8. Filling the missing values of 'AgeCategory' field

# %%
dataset['AgeCategory'].isna().sum() #Checking if missing values exists in 'AgeCategory' field
# Out:
# 44

# %%
dataset['AgeCategory'] #Checking the values of 'AgeCategory'
# Out:
# 0               55-59
# 1         80 or older
# 2               65-69
# 3               75-79
# 4               40-44
#              ...
# 319790          60-64
# 319791          35-39
# 319792          45-49
# 319793          25-29
# 319794    80 or older
# Name: AgeCategory, Length: 319795, dtype: object

# %%
dataset['AgeCategory'].fillna(45-49, inplace=True) #Filling all the missing values of 'AgeCategory' field

# %%
dataset[dataset['AgeCategory']==45-49] #Selecting all the values that we just filled
# Out:
#      HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 1034           No  39.32      No              No     No             7.0
# 1035          Yes  19.64      No              No     No             1.0
# 1036           No  35.71      No              No     No             0.0
# 1037           No  37.25     Yes              No     No             5.0
# 1038           No  28.90      No              No    Yes             0.0
# 1039           No  32.08      No              No     No             0.0
# 1040           No  35.40     Yes              No     No            14.0
# 1041           No  28.52     Yes              No     No            20.0
# 1042           No  21.62     Yes              No     No             0.0
# 1043           No  22.85      No              No     No             0.0
# 1044           No  30.72     Yes              No     No             0.0
# 1045           No  32.26     Yes              No     No             6.0
# ...

# %% [markdown]
# #### 9. Filling the missing values of 'Race' field

# %%
dataset['Race'].isna().sum() #Checking if the missing values exists
# Out:
# 39

# %%
dataset['Race'] #Checking the values of 'Race' field
# Out:
# 0            White
# 1            White
# 2            White
# 3            White
# 4            White
#             ...
# 319790    Hispanic
# 319791    Hispanic
# 319792    Hispanic
# 319793    Hispanic
# 319794    Hispanic
# Name: Race, Length: 319795, dtype: object

# %%
dataset['Race'].unique() #Selecting the unique values of 'Race' field
# Out:
# array(['White', 'Black', 'Asian', 'American Indian/Alaskan Native',
#        'Other', 'Hispanic', nan], dtype=object)

# %%
dataset['Race'].fillna('African', inplace=True) #Filling the missing values in 'Race' field

# %%
dataset[dataset['Race']=='African'] #Selecting the values we just filled in 'Race' field
# Out:
#      HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 1024           No  26.45     Yes              No     No             5.0
# 1025           No  38.41     Yes              No    Yes            15.0
# 1026           No  25.29     Yes              No    Yes             0.0
# 1027           No  28.70      No              No     No            30.0
# 1028          Yes  27.93      No              No    Yes             2.0
# 1029           No  21.93     Yes              No     No            30.0
# 1030           No  29.12     Yes              No     No             0.0
# 1031           No  36.90     Yes              No     No             5.0
# 1032           No  22.15     Yes              No     No             0.0
# 1033           No  31.46     Yes              No     No            10.0
# 1034           No  39.32      No              No     No             7.0
# 1035          Yes  19.64      No              No     No             1.0
# ...

# %% [markdown]
# #### 10. Filling the missing values of 'Diabetic' field

# %%
dataset['Diabetic'].isna().sum() #Checking the is missing values exists
# Out:
# 33

# %%
dataset['Diabetic'].unique() #Selecting the unique values from 'Diabetic' column
# Out:
# array(['Yes', 'No', 'No, borderline diabetes', 'Yes (during pregnancy)',
#        nan], dtype=object)

# %%
dataset['Diabetic'].fillna('Yes, Sugar', inplace=True) #Filling the missing values in 'Diabetic' column

# %%
dataset[dataset['Diabetic']=='Yes, Sugar'] #Selecting the values we just filled in 'Diabetic' column
# Out:
#      HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 1004          Yes  23.71      No              No     No             0.0
# 1005           No  29.76     Yes              No     No            30.0
# 1006           No  40.90      No              No     No            30.0
# 1007           No  23.49      No              No     No             0.0
# 1008           No  24.02      No              No     No             0.0
# 1009           No  46.06     Yes              No     No            30.0
# 1010           No  37.76     Yes              No     No             0.0
# 1011           No  21.59     Yes              No     No             0.0
# 1012           No  27.99      No              No     No            20.0
# 1013           No  32.14     Yes              No     No             0.0
# 1014           No  28.19     Yes              No     No             2.0
# 1015           No  25.51      No              No     No             0.0
# ...

# %% [markdown]
# #### 11. Filling the missing values in 'PhysicalActivity' column

# %%
dataset['PhysicalActivity'].isna().sum() #Checking if the missing values exists
# Out:
# 16

# %%
dataset['PhysicalActivity'].unique()#Selecting the unique values from 'PhysicalActivity' column
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
dataset['PhysicalActivity'].fillna('No', inplace=True) #Filling the missing values of 'PhysicalActivity' column

# %%
dataset[dataset['PhysicalActivity']=='No'] #Selecting the values we just filled
# Out:
#        HeartDisease     BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 3                No  24.210      No              No     No             0.0
# 5               Yes  28.870     Yes              No     No             6.0
# 7                No  33.303     Yes              No     No             5.0
# 8                No  26.450      No              No     No             0.0
# 10              Yes  34.300     Yes              No     No            30.0
# ...             ...     ...     ...             ...    ...             ...
# 319778           No  26.630      No              No     No             0.0
# 319782           No  31.890     Yes              No     No            30.0
# 319787           No  36.540      No              No     No             7.0
# 319790          Yes  27.410     Yes              No     No             7.0
# 319793           No  32.810      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# ...

# %% [markdown]
# #### 12. Filling the missing values in 'GenHealth' column

# %%
#Checking if the missing values exists in 'GenHealth' column
dataset['GenHealth'].isna().sum()
# Out:
# 493

# %%
dataset['GenHealth'].unique() #Selecting the unique values from 'GenHealth' field
# Out:
# array(['Very good', 'Fair', 'Good', 'Poor', 'Excellent', nan],
#       dtype=object)

# %%
dataset['GenHealth'].fillna('Well', inplace=True) #Filling the missing values in 'GenHealth' column

# %%
dataset[dataset['GenHealth']=='Well'] #Selecting the values we just filled
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 252308           No  20.98      No              No     No             0.0
# 252309           No  21.63      No              No     No             3.0
# 252310          Yes  34.46      No              No     No             0.0
# 252311           No  26.54      No              No     No             0.0
# 252312           No  26.63      No              No     No             2.0
# ...             ...    ...     ...             ...    ...             ...
# 252796           No  21.95     Yes              No     No             0.0
# 252797           No  28.19     Yes              No     No            14.0
# 252798           No  32.55      No              No     No             0.0
# 252799           No  21.97     Yes              No     No             0.0
# 252800           No  28.13      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory  \
# ...

# %% [markdown]
# #### 13. Filling the missing values in 'SleepTime' field

# %%
dataset['SleepTime'].isna().sum() #Checking if missing values exists
# Out:
# 219

# %%
dataset['SleepTime'].unique() #Selecting the unique values
# Out:
# array([ 5.,  7.,  8.,  6., 12.,  4.,  9., 10., 15.,  3.,  2.,  1., 16.,
#        18., 14., 20., 11., 13., 17., 24., 19., 21., 22., 23., nan])

# %%
dataset['SleepTime'].fillna(11.12, inplace=True) #Filling the missing values in 'SleepTime' column

# %%
dataset[dataset['SleepTime']==11.12] #Selecting the values we just filled
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 252291           No  25.75     Yes              No     No             0.0
# 252292           No  26.83     Yes              No     No             0.0
# 252293           No  18.55      No              No     No             0.0
# 252294           No  36.58     Yes              No     No             0.0
# 252295           No  32.32      No              No     No             2.0
# ...             ...    ...     ...             ...    ...             ...
# 253301           No  36.92      No              No     No             0.0
# 253302           No  34.33      No              No     No             0.0
# 253303           No  22.81      No              No     No             0.0
# 253304           No  25.10      No              No     No             0.0
# 253305           No  25.06     Yes              No     No            15.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory  \
# ...

# %% [markdown]
# #### 14. Checking the missing values in 'Asthma' column

# %%
dataset['Asthma'].isna().sum() #No missing values exists
# Out:
# 0

# %% [markdown]
# #### 15. Filling the missing values in 'KidneyDisease' column

# %%
dataset['KidneyDisease'].isna().sum() #Checking if missing values exists
# Out:
# 17

# %%
dataset['KidneyDisease'].unique() #Selecting the unique values
# Out:
# array(['No', nan, 'Yes'], dtype=object)

# %%
dataset['KidneyDisease'].fillna('No', inplace=True) #Filling the missing values

# %%
dataset[dataset['KidneyDisease']=='No'] #Selecting the values we just filled
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# #### 16. Checking if missing values exists in 'SkinCancer' column

# %%
dataset['SkinCancer'].isna().sum() #No missing values exists
# Out:
# 0

# %% [markdown]
# ## Encoding

# %% [markdown]
# ### Label Encoding

# %%
scaler = LabelEncoder()

# %% [markdown]
# #### Encoding 'HeartDisease'

# %%
dataset['HeartDisease_enc'] = scaler.fit_transform(dataset['HeartDisease'])
dataset[['HeartDisease_enc', 'HeartDisease']]
# Out:
#         HeartDisease_enc HeartDisease
# 0                      0           No
# 1                      0           No
# 2                      0           No
# 3                      0           No
# 4                      0           No
# ...                  ...          ...
# 319790                 1          Yes
# 319791                 0           No
# 319792                 0           No
# 319793                 0           No
# 319794                 0           No
#
# [319795 rows x 2 columns]

# %%
dataset
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
dataset['HeartDisease_enc'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# #### Encoding 'BMI'

# %%
dataset['BMI_enc'] = scaler.fit_transform(dataset['BMI'])
dataset[['BMI_enc', 'BMI']]
# Out:
#         BMI_enc    BMI
# 0           223  16.60
# 1           524  20.34
# 2          1103  26.58
# 3           883  24.21
# 4           837  23.71
# ...         ...    ...
# 319790     1180  27.41
# 319791     1397  29.84
# 319792      886  24.24
# 319793     1658  32.81
# 319794     2701  46.56
#
# [319795 rows x 2 columns]

# %% [markdown]
# #### Encoding 'AlcoholDrinking'

# %%
dataset['AlcoholDrinking_enc'] = scaler.fit_transform(dataset['AlcoholDrinking'])
dataset[['AlcoholDrinking_enc','AlcoholDrinking']]
# Out:
#         AlcoholDrinking_enc AlcoholDrinking
# 0                         0              No
# 1                         0              No
# 2                         0              No
# 3                         0              No
# 4                         0              No
# ...                     ...             ...
# 319790                    0              No
# 319791                    0              No
# 319792                    0              No
# 319793                    0              No
# 319794                    0              No
#
# [319795 rows x 2 columns]

# %% [markdown]
# #### Encoding 'MentalHealth'

# %%
dataset['MentalHealth_enc'] = scaler.fit_transform(dataset['MentalHealth'])
dataset[['MentalHealth_enc', 'MentalHealth']]
# Out:
#         MentalHealth_enc  MentalHealth
# 0                     31          30.0
# 1                      0           0.0
# 2                     31          30.0
# 3                      0           0.0
# 4                      0           0.0
# ...                  ...           ...
# 319790                 0           0.0
# 319791                 0           0.0
# 319792                 0           0.0
# 319793                 0           0.0
# 319794                 0           0.0
#
# [319795 rows x 2 columns]

# %% [markdown]
# #### Encoding 'Race'

# %%
dataset['Race_enc'] = scaler.fit_transform(dataset['Race'])
dataset[['Race_enc', 'Race']]
# Out:
#         Race_enc      Race
# 0              6     White
# 1              6     White
# 2              6     White
# 3              6     White
# 4              6     White
# ...          ...       ...
# 319790         4  Hispanic
# 319791         4  Hispanic
# 319792         4  Hispanic
# 319793         4  Hispanic
# 319794         4  Hispanic
#
# [319795 rows x 2 columns]

# %% [markdown]
# #### Encoding 'GenHealth'

# %%
dataset['GenHealth_enc'] = scaler.fit_transform(dataset['GenHealth'])
dataset[['GenHealth_enc', 'GenHealth']]
# Out:
#         GenHealth_enc  GenHealth
# 0                   4  Very good
# 1                   4  Very good
# 2                   1       Fair
# 3                   2       Good
# 4                   4  Very good
# ...               ...        ...
# 319790              1       Fair
# 319791              4  Very good
# 319792              2       Good
# 319793              2       Good
# 319794              2       Good
#
# [319795 rows x 2 columns]

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Scatter Plot

# %%
x = dataset['PhysicalHealth']

# %%
y = dataset['MentalHealth']

# %%
plt.scatter(x, y, label='Data points')  # Add label for legend
plt.title("Scatter Plot of PhysicalHealth vs MentalHealth")
plt.xlabel("Physical Health")
plt.ylabel("Mental Health")
plt.legend(title="Legend", loc='upper left')
plt.show()

# %%
# Define the categorical columns for which you want to create pie charts
categorical_columns = ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke']

# Create pie charts for each categorical column
for column in categorical_columns:
    # Count the occurrences of each category
    counts = dataset[column].value_counts()
    
    # Create a pie chart
    plt.figure()
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140)
    plt.title(f'Proportion of {column}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
dataset
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory  ... SleepTime Asthma  \
# ...

# %%
# Count the occurrences of each category in the 'Sex' column
sex_counts = dataset['Sex'].value_counts()

# Create a pie chart
plt.figure()
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Proportion of Sex")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
dataset_info = dataset.describe()
dataset_info
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime  \
# count  319795.000000   319795.000000  319795.000000  319795.000000
# mean       28.325442        3.372016       3.899186       7.099677
# std         6.356111        7.950651       7.956040       1.439526
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.340000        0.000000       0.000000       7.000000
# 75%        31.430000        2.000000       3.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000
#
#        HeartDisease_enc        BMI_enc  AlcoholDrinking_enc  MentalHealth_enc  \
# count     319795.000000  319795.000000        319795.000000     319795.000000
# mean           0.085595    1242.323485             0.068441          3.963258
# std            0.279766     533.254439             0.252501          8.162342
# ...

# %%
# Line plot: HeartDisease vs. BMI
plt.figure(figsize=(8, 6))
plt.plot(dataset['BMI'], dataset['HeartDisease'], marker='o', linestyle='--')
plt.xlabel('BMI')
plt.ylabel('Heart Disease')
plt.title('Heart Disease vs. BMI')
plt.show()

# %%
# Bar plot: Count of individuals with different SkinCancer values
plt.figure(figsize=(8, 6))
skin_cancer_counts = dataset['SkinCancer'].value_counts()
plt.bar(skin_cancer_counts.index, skin_cancer_counts.values)
plt.xlabel('Skin Cancer')
plt.ylabel('Count')
plt.title('Distribution of Skin Cancer')
plt.show()

# %%
# Create a copy of the DataFrame to preserve the original data
encoded_df = dataset.copy()

# Identify the categorical columns
categorical_cols = encoded_df.select_dtypes(include=['object']).columns

# One-hot encode the categorical columns
encoded_df = pd.get_dummies(encoded_df, columns=categorical_cols)

# Scatter plot: Physical Health vs. Mental Health
plt.figure(figsize=(10, 6))
plt.scatter(encoded_df['PhysicalHealth'], encoded_df['MentalHealth'])
plt.xlabel('Physical Health')
plt.ylabel('Mental Health')
plt.title('Physical Health vs. Mental Health')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 8))
corr_matrix = encoded_df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.tight_layout(pad=3.0)# Adjust the layout to prevent overlapping
plt.subplots_adjust(hspace=0.5, wspace=0.9)
  
plt.show()
